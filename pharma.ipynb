# %%
# %matplotlib inline 
import pandas.io.sql as psql
import pandas as pd
import numpy as np
import MySQLdb as sql
from matplotlib import pyplot as plt
import csv
pd.options.display.max_rows = 8

# %% [markdown]
# ### Medicare doctor demographic information and program participation

# %% [markdown]
# * Medicare's Official Physician Compare Data:  https://data.medicare.gov/data/physician-compare
# * Updated May 1, 2015

# %%
drs = pd.read_csv('drs.csv')
drs = drs.set_index('NPI')
drs.iloc[0:1]
# Out:
#                 PAC ID Professional Enrollment ID   Last Name First Name  \
# NPI
# 1003001843  5597718650            I20050301000433  LUECHINGER       INGE
#
#            Middle Name Suffix Gender Credential Medical school name  \
# NPI
# 1003001843           C    NaN      F        CNS               OTHER
#
#             Graduation year               ...                \
# NPI                                       ...
# 1003001843             1998               ...
#
#            Claims based hospital affiliation CCN 4  \
# NPI
# 1003001843                                     NaN
#
#            Claims based hospital affiliation LBN 4  \
# NPI
# 1003001843                                     NaN
#
#            Claims based hospital affiliation CCN 5  \
# NPI
# 1003001843                                     NaN
#
#            Claims based hospital affiliation LBN 5  \
# NPI
# 1003001843                                     NaN
#
# ...

# %% [markdown]
# ### Payments to physicians

# %% [markdown]
# * Open Payments data from the Centers for Medicare and Medicaid obtained from http://www.cms.gov/OpenPayments/Explore-the-Data/Dataset-Downloads.html
# * Covers calendar year 2013.
# * A complete set of general, research, and ownership payments as well as physician profiles from both 9/30/14 and 12/19/14 data publications.
# * More details can be found here: http://www.cms.gov/OpenPayments/Downloads/OpenPaymentsDataDictionary.pdf

# %% [markdown]
# #### General payments details

# %%
money = pd.read_csv('money.csv',dtype=object)
money = money.set_index('Physician_Profile_ID')
money.ix[0:1]
# Out:
#                      Unnamed: 0 General_Transaction_ID Program_Year  \
# Physician_Profile_ID
# 27216                         0                  31341         2013
#
#                      Payment_Publication_Date  \
# Physician_Profile_ID
# 27216                              09/30/2014
#
#                      Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# Physician_Profile_ID
# 27216                                             Cardiosolutions, Inc.
#
#                            Covered_Recipient_Type Teaching_Hospital_ID  \
# Physician_Profile_ID
# 27216                 Covered Recipient Physician                  NaN
#
#                      Teaching_Hospital_Name Physician_First_Name  \
# Physician_Profile_ID
# 27216                                   NaN               Thomas
#
#                      Physician_Middle_Name  \
# Physician_Profile_ID
# 27216                                  NaN
#
# ...

# %% [markdown]
# Associated fields

# %%
for col in money.columns:
    print col
# Out:
# Unnamed: 0
# General_Transaction_ID
# Program_Year
# Payment_Publication_Date
# Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name
# Covered_Recipient_Type
# Teaching_Hospital_ID
# Teaching_Hospital_Name
# Physician_First_Name
# Physician_Middle_Name
# Physician_Last_Name
# Physician_Name_Suffix
# Recipient_Primary_Business_Street_Address_Line1
# Recipient_Primary_Business_Street_Address_Line2
# Recipient_City
# Recipient_State
# Recipient_Zip_Code
# Recipient_Country
# Recipient_Province
# Recipient_Postal_Code
# Physician_Primary_Type
# Physician_Specialty
# Physician_License_State_code1
# Physician_License_State_code2
# Physician_License_State_code3
# Physician_License_State_code4
# Physician_License_State_code5
# Product_Indicator
# Name_of_Associated_Covered_Drug_or_Biological1
# Name_of_Associated_Covered_Drug_or_Biological2
# Name_of_Associated_Covered_Drug_or_Biological3
# Name_of_Associated_Covered_Drug_or_Biological4
# Name_of_Associated_Covered_Drug_or_Biological5
# ...

# %%
fig,ax= plt.subplots(nrows=1, ncols=1)
ax.set_ylabel('Number of payments',fontsize=20)
money['Name_of_Associated_Covered_Drug_or_Biological1'].value_counts()[:20].plot(kind='bar',ax=ax)

# %% [markdown]
# #### Research payments details

# %%
owners = pd.read_csv('owners.csv',dtype=object)
owners = owners.set_index('Physician_Profile_ID')
owners.ix[0:1]
# Out:
#                      Physician_Ownership_Transaction_ID Program_Year  \
# Physician_Profile_ID
# 27216                                                10         2013
#
#                      Payment_Publication_Date  \
# Physician_Profile_ID
# 27216                              09/30/2014
#
#                      Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# Physician_Profile_ID
# 27216                                             Cardiosolutions, Inc.
#
#                      Physician_First_Name Physician_Middle_Name  \
# Physician_Profile_ID
# 27216                              Thomas                   NaN
#
#                      Physician_Last_Name Physician_Name_Suffix  \
# Physician_Profile_ID
# 27216                           Piemonte                   NaN
#
#                      Recipient_Primary_Business_Street_Address_Line1  \
# Physician_Profile_ID
# 27216                                                   Lahey Clinic
#
# ...

# %%
research = pd.read_csv('research.csv',dtype=object)
research = research.set_index('Physician_Profile_ID')
research.ix[0:1]
# Out:
#                      Research_Transaction_ID Program_Year  \
# Physician_Profile_ID
# NaN                                      100         2013
#
#                      Payment_Publication_Date  \
# Physician_Profile_ID
# NaN                                09/30/2014
#
#                      Submitting_Applicable_Manufacturer_or_Applicable_GPO_Name  \
# Physician_Profile_ID
# NaN                                                  Incyte Corporation
#
#                                    Covered_Recipient_Type  \
# Physician_Profile_ID
# NaN                   Covered Recipient Teaching Hospital
#
#                      Noncovered_Recipient_Entity_Name Teaching_Hospital_ID  \
# Physician_Profile_ID
# NaN                                               NaN                   46
#
#                          Teaching_Hospital_Name Physician_First_Name  \
# Physician_Profile_ID
# NaN                   The Mount Sinai Hospital.                  NaN
#
# ...

# %%
paiddoctors = pd.read_csv('paiddoctors.csv',dtype=object)
paiddoctors = paiddoctors.set_index('Physician_Profile_ID')
paiddoctors.ix[0:1]
# Out:
#                      ﻿"Physician_ID" Physician_Profile_First_Name  \
# Physician_Profile_ID
# 531101                        302447                         SAUD
#
#                      Physician_Profile_Middle_Name  \
# Physician_Profile_ID
# 531101                                           M
#
#                      Physician_Profile_Last_Name  \
# Physician_Profile_ID
# 531101                                 . FAROOQI
#
#                      Physician_Profile_Suffix_Name Physician_Profile_Address1  \
# Physician_Profile_ID
# 531101                                         NaN         ON025 WINFIELD RD.
#
#                      Physician_Profile_Address2 Physician_Profile_City  \
# Physician_Profile_ID
# 531101                                      NaN               WINFIELD
#
#                      Physician_Profile_State Physician_Profile_Zip_Code  \
# Physician_Profile_ID
# 531101                                    IL                      60190
#
# ...

# %% [markdown]
# ### Medicare prescription data

# %% [markdown]
# *   Medicare Provider Utilization and Payment Data from the Centers for Medicare and Medicaid from http://www.cms.gov/Research-Statistics-Data-and-Systems/Statistics-Trends-and-Reports/Medicare-Provider-Charge-Data/Part-D-Prescriber.html
# * Covers calendar year 2013

# %%
Rxs = pd.read_csv('rxs.csv')
Rxs = Rxs.set_index('NPI')
Rxs.iloc[0:1]
# Out:
#            NPPES_PROVIDER_LAST_ORG_NAME NPPES_PROVIDER_FIRST_NAME  \
# NPI
# 1821285826    21ST CENTURY ONCOLOGY LLC                       NaN
#
#            NPPES_PROVIDER_CITY NPPES_PROVIDER_STATE SPECIALTY_DESC  \
# NPI
# 1821285826            AVENTURA                   FL        Urology
#
#            DESCRIPTION_FLAG       DRUG_NAME    GENERIC_NAME  BENE_COUNT  \
# NPI
# 1821285826                S  TAMSULOSIN HCL  TAMSULOSIN HCL         NaN
#
#             TOTAL_CLAIM_COUNT  TOTAL_DAY_SUPPLY  TOTAL_DRUG_COST  \
# NPI
# 1821285826                 12               360           142.14
#
#             BENE_COUNT_GE65 BENE_COUNT_GE65_REDACT_FLAG  \
# NPI
# 1821285826              NaN                           *
#
#             TOTAL_CLAIM_COUNT_GE65 GE65_REDACT_FLAG  TOTAL_DAY_SUPPLY_GE65  \
# NPI
# 1821285826                     NaN                *                    NaN
#
#             TOTAL_DRUG_COST_GE65
# NPI
# 1821285826                   NaN

# %% [markdown]
# ### Prescription drugs and their manufacturers

# %% [markdown]
# Data obtained from the FDA's national drug code registry: http://www.fda.gov/Drugs/InformationOnDrugs/ucm142438.htm

# %%
drugs = pd.read_csv('drugs.csv')
drugs = drugs.set_index('PRODUCTID')
drugs.ix[0:1]
# Out:
#                                                PRODUCTNDC  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee  0002-1200
#
#                                                         PRODUCTTYPENAME  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee  HUMAN PRESCRIPTION DRUG
#
#                                                PROPRIETARYNAME  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee          Amyvid
#
#                                                PROPRIETARYNAMESUFFIX  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee                   NaN
#
#                                                NONPROPRIETARYNAME  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee   Florbetapir F 18
#
#                                                      DOSAGEFORMNAME  \
# PRODUCTID
# 0002-1200_90cd7556-b011-4f13-bd57-cc0f162267ee  INJECTION, SOLUTION
#
#                                                   ROUTENAME  \
# PRODUCTID
# ...
